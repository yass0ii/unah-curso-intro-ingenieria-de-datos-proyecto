# %% [markdown]
# # Web scraping: THE WORLD FACTBOOK
#
# ## Introducción
#
# "The World Factbook" de la CIA es una publicación en línea que proporciona información detallada sobre diversos países y territorios de todo el mundo. Es una referencia ampliamente utilizada y una de las fuentes de información más completas y confiables sobre datos demográficos, geográficos, económicos, políticos y militares de diferentes naciones.
# <br>
# La página web de "The World Factbook" de la CIA ofrece un amplio conjunto de datos sobre más de 250 países y territorios (262 para el 14 de junio del 2023). Proporciona información sobre aspectos como la geografía, la población, el gobierno, la economía, las comunicaciones, las fuerzas militares y mucho más. Estos datos incluyen descripciones, estadísticas, gráficos y mapas que permiten obtener una visión general de cada país o territorio.
#
#
# ## Objetivos
#
# ### Generales
# - Recopilar datos desde una página web por medio de métodos de programación tradicional.
#
# ### Especifícos
# - Analizar la estructura del contenidos de la página web `The World Factbook`.
# - Extraer datos mediante el uso de técnicas de web scrapping utilizando el lenguaje de programación Python.
# - Modelar y diseñar la base de datos que almacenará los datos sustraidos de la página web `The World factbook`.
#
#
# ## Descripción del problema
# El objetivo de este proyecto es realizar un proceso de Web Scraping en la página web "[The World factbook](https://www.cia.gov/the-world-factbook/)" para extraer datos relevantes sobre diversos países. Utilizando el lenguaje de programación Python y la biblioteca BeautifulSoup, se llevará a cabo la extracción y procesamiento de la información disponible en la página web.
#
# Una vez obtenidos los datos, se almacenarán en un archivo plano en formato JSON, lo cual permitirá su posterior manipulación y análisis. El siguiente paso consistirá en realizar un proceso de ETL (Extracción, Transformación y Carga) para transferir los datos extraídos desde el archivo JSON a una base de datos relacional.
#
# La base de datos relacional será utilizada como fuente de información para responder a las preguntas planteadas en el contexto del proyecto. Mediante consultas a la base de datos, se podrán obtener estadísticas, características y visualizaciones relevantes sobre los países y sus atributos.
#
# Este proyecto tiene como finalidad demostrar las habilidades en Web Scraping, procesamiento de datos y manejo de bases de datos relacionales. Además, proporcionará una oportunidad para aplicar técnicas de visualización de datos y responder preguntas analíticas a partir de la información recopilada.
#
# A través de este proyecto, se espera que los participantes adquieran experiencia práctica en la obtención de datos, manipulación de información, modelado de datos y generación de conocimiento a partir de los mismos.
#
#
# ## 1. - Actividades
#
# 1. **Exploración del sitio web [The World factbook](https://www.cia.gov/the-world-factbook/)**
#     - Análisis inicial: Revisar, leer y explorar el sitio web.
#     - Revisar, leer y explorar la estructura `HTML` del sitio web.
#     - Reconocer diferentes etiquetas de contenido.
#     -  **Análisis**: Es necesario estudiar la estructura del `HTML` para la pagina web `The world factbook`, esta estructura es una pauta _inicial-esencial_ para la identificación de las etiquetas  que contienen caracteristicas de interes. Por ejemplo:
#        - titulos contenidos en etiquetas `<h2></h2>`
#        - subtitulos contenidos en etiquetas `<h3></h3>`
#        - parrafos contenidos en etiquetas `<p></p>`
#
#
# <br>
#
# 2. **Extracción de los datos**
#     - Haciendo uso de la herramienta `Jupyter Notebook` programar los módulos necesarios que responden a la necesidad de extraer el contenido de la página web.
#     - Extraer de la página web los datos identificados a partir del lenguaje de programación Python utilizando la `librería BeautifulSoup`.
#     - Extraer la información de cada uno de los países (historia, población, gobierno, economía, geografía, medio ambiente, comunicaciones, transporte...).
#     - Mediante el uso de python, hacer un pre procesamiento de los datos (extracción y limpieza, es decir obtener el texto plano sin etiquetas HTML, sin espacios en blanco).
#     - Guardar los datos para cada país en un archivo (único) plano en formato JSON.
#         - Respetando la estructura `clave:valor` del archivo con formato JSON
#
# <br>
#
# 3. **SQL**
#     - Crear un modelo `entidad relación` que responda a las preguntas de negocio (*leer detenidamente el inciso 5*).
#         - Crear la entidad.
#         - Identificar atributos.
#     - Esquematizar la base de datos, pasar del modelo `Entidad relación` al `lenguaje de definición de datos` (DDL).
#     - Crear una base de datos en MySQL con el nombre `IIDDBDWorldFactbook`.
#     - Crear una tabla en la base de datos `IIDDBDWorldFactbook` con el nombre `WorldFactbookDataAnalysis` con sus correspondientes campos, tipos de datos, etc.
#
# **Nota**:
# Será importante identificar los campos que respondan a las preguntas exploratorias del inciso 5. Estos campos se refieren a los datos estructurados contenidos en el archivo plano en formato JSON. <br>
# Por ejemplo, `¿Cuáles son los países más y menos poblados?` quiere decir que existirá un atributo en la tabla `WorldFactbookDataAnalysis` llamado `population` que contiene el número total de población correspondiente a cada país.
#
# <br>
#
# 4. **ETL**
#     - Mediante el uso de la herramienta de integración de datos, Talend, realizar un ETL (Extracción, Transformación y Carga) al archivo plano en formato JSON que contiene la información de los países.
#     - Mapear los datos (keys) del archivo plano en formato JSON con los campos de la tabla `WorldFactbookDataAnalysis`.
#     - Entregar un único archivo que es un JOB con los componentes que realicen lo pedido.
#     - Debe entregar una captura de pantalla con el JOB que contiene los componentes (una única imagen) con el nombre `etl.png`
#
#
# <br>
#
# 5. **Responder a las preguntas para explorar los datos**
#
#     5.1. *Población:*
#     - ¿Cuáles son los países más y menos poblados?
#     - ¿Cuál es la densidad de población promedio por región o continente?
#     - ¿Cuáles son los países con la tasa de crecimiento demográfico más alta o más baja?
#
#     5.2. *Economía:*
#     - ¿Cuáles son las principales economías del mundo en términos de PIB?
#     - ¿Cuáles son los países con el ingreso per cápita más alto o más bajo?
#     - ¿Cuáles son los sectores económicos más importantes en diferentes países?
#
#     5.3. *Geografía:*
#     - ¿Cuáles son los países más grandes y más pequeños en términos de área?
#     - ¿Cuál es la longitud de las costas de diferentes países?
#     - ¿Cuáles son los países con la altitud más alta o más baja?
#
#     5.4. *Educación:*
#     - ¿Cuáles son los países con los niveles más altos de alfabetización?
#     - ¿Cuál es la tasa de matriculación escolar en diferentes países?
#     - ¿Cuáles son los países con la mayor inversión en educación?
#
#     5.5. *Salud:*
#     - ¿Cuál es la esperanza de vida promedio en diferentes países?
#     - ¿Cuáles son los países con la tasa de mortalidad infantil más alta o más baja?
#     - ¿Cuáles son los principales problemas de salud en diferentes regiones?
#
# <br>
#
# 6. **Resultados y conclusiones**
#    - Se espera un único archivo `ipynb` llamado `webScrapingCIA.ipynb`.
#    - Una carpeta llamada `core` que contendrá los paquetes de programaciñn desarrollados por el estudiante y que responden a la parte de extracción de los datos.
#    - Una carpeta llamada `data` que contendrá el archivo plano en formato JSON con la información extraída del sitio web [The World factbook](https://www.cia.gov/the-world-factbook/).
#    - Una carpeta llamada `SQL` que contendrá la definición de la base datos, la solución a las preguntas exploratorias y el modelo relacional de la base de datos que será exportado aplicando ingeniería inversa a la base de datos mediante la herramienta de visualización de MySQL.
#    - Una carpeta llamada `ER` dentro de la carpeta `SQL` que contiene el modelo entidad-relación con nombre `er.png` este corresponde a la tabla de la base de datos `IIDDBDWorldFactbook`.
#    - Una carpeta llamada `ETL` que contendrá el JOB y una captura de pantalla con el JOB que contiene los componentes (una única imagen) con el nombre `etl.png`
#    - El siguiente es un ejemplo de la estructura de carpetas de lo esperado:
#      - ETL
#        - `world-factbook.item`
#        - `etl.png`
#      - SQL
#        - `dml-web-scraping.sql`
#        - `ddl-web-scraping.sql`
#        - ER
#            - `er.png`
#      - data
#        - `world-factbook.json`
#      - core
#        - `ExtractHTML.py`
#        - `ProcessHTML.py`
#        - `Tools.py`
#        - ...

# %%
import json
import os
from bs4 import BeautifulSoup

from core.Tools import Tools
from core.ExtractHTML import ExtractHTML
from core.ProcessHTML import ProcessHTML

if __name__ == "__main__":
    
    tools = Tools()
    
    baseURL = "https://www.cia.gov/the-world-factbook/countries"
    RAWCountries = tools.readFile(path=".", name="countries.txt")
    
    e = ExtractHTML(baseURL)
    """
    data = {
        e.conver_to_lower(countrie): 
            str(
                e.get_info_by_class(
                    e.get_info_by_contrie(e.format_country_name(e.conver_to_lower(countrie))),
                    "article-content",
                    "div"
                )
            ) for countrie in RAWCountries
    }
    
    tools.saveFileJson("data", "datos_paises_html.json", data)
    """

# %%
json_data = tools.readFileJson("data", "datos_paises_html.json")
p = ProcessHTML()

data_to_save = {}

# TODOS LOS PAISES
for countrie in RAWCountries:
    data = {}
    divs = p.get_divs(json_data[e.conver_to_lower(countrie)])

    # Recorrer cada div encontrado
    for div in divs:
        h2_value = p.get_value_h2(div)
        h3_tags = p.get_alls_h3(div)
        h3_data = {}
        
        for h3_tag in h3_tags:
            h3_value = h3_tag.text.strip() # Valor del <h3>valor</h3>
            
            if h3_value == "Population":
                h3_data[h3_value] = p.get_value_p(h3_tag)
            else:
                h3_data[h3_value] = p.parse_p_tags(h3_tag.find_next('p'))#Valor del <p>valor</p> o {} 
            
        data[h2_value] = h3_data # Agrega el json como key: h2: value: TODO lo que se proceso en los tags de h3
        
    data_to_save[e.conver_to_lower(countrie)] = data
    
tools.saveFileJson("data", "data_json_1.json", data_to_save)
# Out:
# Guardado con exito

# %%
json_data = tools.readFileJson("data", "data_json_1.json")
elements = ["Geography", "People and Society", "Economy"]

final_data = {}

# EXTRACCION DE INFORMACION NECESARIA
for countrie in RAWCountries:
    country_lower = e.conver_to_lower(countrie)
    
    if country_lower in json_data:
        country_info = json_data[country_lower]
        country_data = {}
        
        for element in elements:
            if element in country_info:
                country_data[element] = country_info[element]
        
        final_data[country_lower] = country_data
    else:
        print(f"Data not found for {countrie}")

tools.saveFileJson("data", "data_json_2.json", final_data)
# Out:
# Guardado con exito

# %%
json_data = tools.readFileJson("data", "data_json_2.json")
elements = ["Geography", "People and Society", "Economy"]
p = ProcessHTML()
final_data = {}

for pais in RAWCountries:
    country_lower = e.conver_to_lower(pais)
    countrie = json_data[country_lower]
    
    c = {
        'countrie': country_lower,
        'population': float(p.get_population( countrie.get('People and Society', {}).get('Population', '') )),
        'Population growth rate': p.limpiar_porcentaje( countrie.get('People and Society', {}).get('Population growth rate', '') ),
        'area': p.limpiar_campos( countrie.get('Geography', {}).get('Area', {}).get('total:', '') ),
        'Map references': countrie.get('Geography', {}).get('Map references', ''),
        'Coastline': float(p.limpiar_campos( countrie.get('Geography', {}).get('Coastline', '') )) if p.limpiar_campos( countrie.get('Geography', {}).get('Coastline', '') ) != '' else 0,
        'elevation highest point': p.limpiar( countrie.get('Geography', {}).get('Elevation', {}).get('highest point:', '') ),
        'elevation lowest point': p.limpiar( countrie.get('Geography', {}).get('Elevation', {}).get('lowest point:', '') ),
        'economy': {
            'GDP': p.procces_gpd( countrie.get('Economy', {}).get('GDP (official exchange rate)', '') ),
            'GDP_contribution_agriculture': p.limpiar_porcentaje( countrie.get('Economy', {}).get('GDP - composition, by sector of origin', {}).get('agriculture:', '') ),
            'GDP_contribution_industry': p.limpiar_porcentaje( countrie.get('Economy', {}).get('GDP - composition, by sector of origin', {}).get('industry:', '') ),
            'GDP_contribution_services': p.limpiar_porcentaje( countrie.get('Economy', {}).get('GDP - composition, by sector of origin', {}).get('services:', '') ),
        },
        'education': {
            'school life expectancy': p.limpiar_campos( countrie.get('People and Society', {}).get('School life expectancy (primary to tertiary education)', {}).get('total:', '') ),
            'Education expenditures': p.limpiar_porcentaje( countrie.get('People and Society', {}).get('Education expenditures', '') ),
        },
        'health': {
            'life expectancy at birth': p.limpiar_campos( countrie.get('People and Society', {}).get('Life expectancy at birth', {}).get('total population:', '') ),
            'infant mortality rate': p.get_decimal( countrie.get('People and Society', {}).get('Infant mortality rate', {}).get('total:', '') ),
            'Health problems': {
                'Current health expenditure': p.limpiar_porcentaje( countrie.get('People and Society', {}).get('Current health expenditure', '') ),
                'Physicians density': p.get_decimal( countrie.get('People and Society', {}).get('Physicians density', '') ),
                'Hospital bed density': p.get_decimal( countrie.get('People and Society', {}).get('Hospital bed density', '') ),
            }
        }
    }
    
    final_data[country_lower] = c

tools.saveFileJson("data", "world-factbook.json", final_data)
# Out:
# Guardado con exito

# %%
json_data = tools.readFileJson("data", "world-factbook.json")



for pais in RAWCountries:
    country_lower = e.conver_to_lower(pais)
    countrie = json_data[country_lower]
    
    print(json.dumps(countrie, indent=4))
# Out:
# {
#     "countrie": "afghanistan",
#     "population": 39232003.0,
#     "Population growth rate": 2.26,
#     "area": 652230.0,
#     "Map references": "Asia",
#     "Coastline": 0.0,
#     "elevation highest point": 7492.0,
#     "elevation lowest point": 258.0,
#     "economy": {
#         "GDP": 20240000000.0,
#         "GDP_contribution_agriculture": 23.0,
#         "GDP_contribution_industry": 21.1,
#         "GDP_contribution_services": 55.9
#     },
#     "education": {
#         "school life expectancy": 10.0,
#         "Education expenditures": 2.9
#     },
#     "health": {
#         "life expectancy at birth": 54.05,
#         "infant mortality rate": "103.06",
#         "Health problems": {
#             "Current health expenditure": 15.5,
#             "Physicians density": "0.25",
#             "Hospital bed density": "0.4"
#         }
#     }
# }
# {
#     "countrie": "akrotiri",
#     "population": 36390.0,
#     "Population growth rate": 0,
#     "area": 123.0,
#     "Map references": "Middle East",
#     "Coastline": 56.3,
#     "elevation highest point": 0,
#     "elevation lowest point": 0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0,
#         "GDP_contribution_industry": 0,
#         "GDP_contribution_services": 0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 0,
#         "infant mortality rate": 0,
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "albania",
#     "population": 3101621.0,
#     "Population growth rate": 0.19,
#     "area": 28748.0,
#     "Map references": "Europe",
#     "Coastline": 362.0,
#     "elevation highest point": 2764.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 15273000000.0,
#         "GDP_contribution_agriculture": 21.7,
#         "GDP_contribution_industry": 24.2,
#         "GDP_contribution_services": 54.1
#     },
#     "education": {
#         "school life expectancy": 14.0,
#         "Education expenditures": 3.1
#     },
#     "health": {
#         "life expectancy at birth": 79.7,
#         "infant mortality rate": "10.54",
#         "Health problems": {
#             "Current health expenditure": 6.7,
#             "Physicians density": "1.88",
#             "Hospital bed density": "2.9"
#         }
#     }
# }
# {
#     "countrie": "algeria",
#     "population": 44758398.0,
#     "Population growth rate": 1.27,
#     "area": 2381740.0,
#     "Map references": "Africa",
#     "Coastline": 998.0,
#     "elevation highest point": 2908.0,
#     "elevation lowest point": -40.0,
#     "economy": {
#         "GDP": 169912000000.0,
#         "GDP_contribution_agriculture": 13.3,
#         "GDP_contribution_industry": 39.3,
#         "GDP_contribution_services": 47.4
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 7.0
#     },
#     "health": {
#         "life expectancy at birth": 78.27,
#         "infant mortality rate": "19.22",
#         "Health problems": {
#             "Current health expenditure": 6.3,
#             "Physicians density": "1.72",
#             "Hospital bed density": "1.9"
#         }
#     }
# }
# {
#     "countrie": "american samoa",
#     "population": 44620.0,
#     "Population growth rate": 1.74,
#     "area": 224.0,
#     "Map references": "Oceania",
#     "Coastline": 116.0,
#     "elevation highest point": 964.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 658000000.0,
#         "GDP_contribution_agriculture": 27.4,
#         "GDP_contribution_industry": 12.4,
#         "GDP_contribution_services": 60.2
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 75.58,
#         "infant mortality rate": "9.87",
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "andorra",
#     "population": 85468.0,
#     "Population growth rate": 0.11,
#     "area": 468.0,
#     "Map references": "Europe",
#     "Coastline": 0.0,
#     "elevation highest point": 2946.0,
#     "elevation lowest point": 840.0,
#     "economy": {
#         "GDP": 2712000000.0,
#         "GDP_contribution_agriculture": 11.9,
#         "GDP_contribution_industry": 33.6,
#         "GDP_contribution_services": 54.5
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 2.9
#     },
#     "health": {
#         "life expectancy at birth": 83.61,
#         "infant mortality rate": "3.39",
#         "Health problems": {
#             "Current health expenditure": 9.1,
#             "Physicians density": "3.63",
#             "Hospital bed density": "2.5"
#         }
#     }
# }
# {
#     "countrie": "angola",
#     "population": 35981281.0,
#     "Population growth rate": 3.34,
#     "area": 1246700.0,
#     "Map references": "Africa",
#     "Coastline": 1600.0,
#     "elevation highest point": 2620.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 97261000000.0,
#         "GDP_contribution_agriculture": 10.2,
#         "GDP_contribution_industry": 61.4,
#         "GDP_contribution_services": 28.4
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 2.4
#     },
#     "health": {
#         "life expectancy at birth": 62.51,
#         "infant mortality rate": "57.2",
#         "Health problems": {
#             "Current health expenditure": 2.9,
#             "Physicians density": "0.21",
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "anguilla",
#     "population": 19079.0,
#     "Population growth rate": 1.77,
#     "area": 91.0,
#     "Map references": "Central America and the Caribbean",
#     "Coastline": 61.0,
#     "elevation highest point": 73.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 175400000.0,
#         "GDP_contribution_agriculture": 3.0,
#         "GDP_contribution_industry": 10.5,
#         "GDP_contribution_services": 86.4
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 4.0
#     },
#     "health": {
#         "life expectancy at birth": 82.41,
#         "infant mortality rate": "3.02",
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "antarctica",
#     "population": 19234.0,
#     "Population growth rate": 0,
#     "area": 14.2,
#     "Map references": "Antarctic Region",
#     "Coastline": 17968.0,
#     "elevation highest point": 4892.0,
#     "elevation lowest point": -3500.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0,
#         "GDP_contribution_industry": 0,
#         "GDP_contribution_services": 0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 0,
#         "infant mortality rate": 0,
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "antigua and barbuda",
#     "population": 101489.0,
#     "Population growth rate": 1.13,
#     "area": 0,
#     "Map references": "Central America and the Caribbean",
#     "Coastline": 153.0,
#     "elevation highest point": 402.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 1524000000.0,
#         "GDP_contribution_agriculture": 1.8,
#         "GDP_contribution_industry": 20.8,
#         "GDP_contribution_services": 77.3
#     },
#     "education": {
#         "school life expectancy": 15.0,
#         "Education expenditures": 3.8
#     },
#     "health": {
#         "life expectancy at birth": 78.04,
#         "infant mortality rate": "13.95",
#         "Health problems": {
#             "Current health expenditure": 5.6,
#             "Physicians density": "2.76",
#             "Hospital bed density": "2.9"
#         }
#     }
# }
# {
#     "countrie": "argentina",
#     "population": 46621847.0,
#     "Population growth rate": 0.8,
#     "area": 2780400.0,
#     "Map references": "South America",
#     "Coastline": 4989.0,
#     "elevation highest point": 6962.0,
#     "elevation lowest point": -105.0,
#     "economy": {
#         "GDP": 447467000000.0,
#         "GDP_contribution_agriculture": 10.8,
#         "GDP_contribution_industry": 28.1,
#         "GDP_contribution_services": 61.1
#     },
#     "education": {
#         "school life expectancy": 18.0,
#         "Education expenditures": 5.0
#     },
#     "health": {
#         "life expectancy at birth": 78.55,
#         "infant mortality rate": "9.14",
#         "Health problems": {
#             "Current health expenditure": 10.0,
#             "Physicians density": "4.06",
#             "Hospital bed density": "5"
#         }
#     }
# }
# {
#     "countrie": "armenia",
#     "population": 2989091.0,
#     "Population growth rate": 0.4,
#     "area": 29743.0,
#     "Map references": "Asia",
#     "Coastline": 0.0,
#     "elevation highest point": 4090.0,
#     "elevation lowest point": 400.0,
#     "economy": {
#         "GDP": 13694000000.0,
#         "GDP_contribution_agriculture": 16.7,
#         "GDP_contribution_industry": 28.2,
#         "GDP_contribution_services": 54.8
#     },
#     "education": {
#         "school life expectancy": 13.0,
#         "Education expenditures": 2.8
#     },
#     "health": {
#         "life expectancy at birth": 76.4,
#         "infant mortality rate": "11.89",
#         "Health problems": {
#             "Current health expenditure": 12.2,
#             "Physicians density": "4.4",
#             "Hospital bed density": "4.2"
#         }
#     }
# }
# {
#     "countrie": "aruba",
#     "population": 123702.0,
#     "Population growth rate": 1.11,
#     "area": 180.0,
#     "Map references": "Central America and the Caribbean",
#     "Coastline": 68.5,
#     "elevation highest point": 188.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 2700000000.0,
#         "GDP_contribution_agriculture": 0.4,
#         "GDP_contribution_industry": 33.3,
#         "GDP_contribution_services": 66.3
#     },
#     "education": {
#         "school life expectancy": 14.0,
#         "Education expenditures": 5.5
#     },
#     "health": {
#         "life expectancy at birth": 78.25,
#         "infant mortality rate": "11.79",
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "ashmore and cartier islands",
#     "population": 0.0,
#     "Population growth rate": 0.32,
#     "area": 5.0,
#     "Map references": "Southeast Asia",
#     "Coastline": 74.1,
#     "elevation highest point": 5.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0,
#         "GDP_contribution_industry": 0,
#         "GDP_contribution_services": 0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 0,
#         "infant mortality rate": 0,
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "australia",
#     "population": 26461166.0,
#     "Population growth rate": 1.19,
#     "area": 7741220.0,
#     "Map references": "Oceania",
#     "Coastline": 25760.0,
#     "elevation highest point": 2228.0,
#     "elevation lowest point": -15.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 3.6,
#         "GDP_contribution_industry": 25.3,
#         "GDP_contribution_services": 71.2
#     },
#     "education": {
#         "school life expectancy": 21.0,
#         "Education expenditures": 6.1
#     },
#     "health": {
#         "life expectancy at birth": 83.28,
#         "infant mortality rate": "2.96",
#         "Health problems": {
#             "Current health expenditure": 10.7,
#             "Physicians density": "4.13",
#             "Hospital bed density": "3.8"
#         }
#     }
# }
# {
#     "countrie": "austria",
#     "population": 8940860.0,
#     "Population growth rate": 0.31,
#     "area": 83871.0,
#     "Map references": "Europe",
#     "Coastline": 0.0,
#     "elevation highest point": 3798.0,
#     "elevation lowest point": 115.0,
#     "economy": {
#         "GDP": 445025000000.0,
#         "GDP_contribution_agriculture": 1.3,
#         "GDP_contribution_industry": 28.4,
#         "GDP_contribution_services": 70.3
#     },
#     "education": {
#         "school life expectancy": 16.0,
#         "Education expenditures": 5.1
#     },
#     "health": {
#         "life expectancy at birth": 82.48,
#         "infant mortality rate": "3.2",
#         "Health problems": {
#             "Current health expenditure": 11.5,
#             "Physicians density": "5.29",
#             "Hospital bed density": "7.3"
#         }
#     }
# }
# {
#     "countrie": "azerbaijan",
#     "population": 10420515.0,
#     "Population growth rate": 0.63,
#     "area": 86600.0,
#     "Map references": "Asia",
#     "Coastline": 0.0,
#     "elevation highest point": 4466.0,
#     "elevation lowest point": -28.0,
#     "economy": {
#         "GDP": 48104000000.0,
#         "GDP_contribution_agriculture": 6.1,
#         "GDP_contribution_industry": 53.5,
#         "GDP_contribution_services": 40.4
#     },
#     "education": {
#         "school life expectancy": 14.0,
#         "Education expenditures": 4.3
#     },
#     "health": {
#         "life expectancy at birth": 74.42,
#         "infant mortality rate": "22.93",
#         "Health problems": {
#             "Current health expenditure": 4.6,
#             "Physicians density": "3.17",
#             "Hospital bed density": "4.8"
#         }
#     }
# }
# {
#     "countrie": "bahamas the",
#     "population": 358508.0,
#     "Population growth rate": 0.8,
#     "area": 13880.0,
#     "Map references": "Central America and the Caribbean",
#     "Coastline": 3542.0,
#     "elevation highest point": 1.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 12160000000.0,
#         "GDP_contribution_agriculture": 2.3,
#         "GDP_contribution_industry": 7.7,
#         "GDP_contribution_services": 90.0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 2.8
#     },
#     "health": {
#         "life expectancy at birth": 76.38,
#         "infant mortality rate": "12.52",
#         "Health problems": {
#             "Current health expenditure": 7.6,
#             "Physicians density": "1.94",
#             "Hospital bed density": "3"
#         }
#     }
# }
# {
#     "countrie": "bahrain",
#     "population": 1553886.0,
#     "Population growth rate": 0.85,
#     "area": 760.0,
#     "Map references": "Middle East",
#     "Coastline": 161.0,
#     "elevation highest point": 135.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 38472000000.0,
#         "GDP_contribution_agriculture": 0.3,
#         "GDP_contribution_industry": 39.3,
#         "GDP_contribution_services": 60.4
#     },
#     "education": {
#         "school life expectancy": 16.0,
#         "Education expenditures": 2.2
#     },
#     "health": {
#         "life expectancy at birth": 80.13,
#         "infant mortality rate": "9.98",
#         "Health problems": {
#             "Current health expenditure": 4.2,
#             "Physicians density": "0.93",
#             "Hospital bed density": "1.7"
#         }
#     }
# }
# {
#     "countrie": "united states pacific island wildlife refuges",
#     "population": 1160.0,
#     "Population growth rate": 0,
#     "area": 0,
#     "Map references": "Oceania",
#     "Coastline": 4.8,
#     "elevation highest point": 0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0,
#         "GDP_contribution_industry": 0,
#         "GDP_contribution_services": 0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 0,
#         "infant mortality rate": 0,
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "bangladesh",
#     "population": 167184465.0,
#     "Population growth rate": 0.91,
#     "area": 148460.0,
#     "Map references": "Asia",
#     "Coastline": 580.0,
#     "elevation highest point": 1060.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 329545000000.0,
#         "GDP_contribution_agriculture": 14.2,
#         "GDP_contribution_industry": 29.3,
#         "GDP_contribution_services": 56.5
#     },
#     "education": {
#         "school life expectancy": 12.0,
#         "Education expenditures": 2.1
#     },
#     "health": {
#         "life expectancy at birth": 74.96,
#         "infant mortality rate": "29.58",
#         "Health problems": {
#             "Current health expenditure": 2.6,
#             "Physicians density": "0.67",
#             "Hospital bed density": "0.8"
#         }
#     }
# }
# {
#     "countrie": "barbados",
#     "population": 303431.0,
#     "Population growth rate": 0.24,
#     "area": 430.0,
#     "Map references": "Central America and the Caribbean",
#     "Coastline": 97.0,
#     "elevation highest point": 336.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 4990000000.0,
#         "GDP_contribution_agriculture": 1.5,
#         "GDP_contribution_industry": 9.8,
#         "GDP_contribution_services": 88.7
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 6.5
#     },
#     "health": {
#         "life expectancy at birth": 78.79,
#         "infant mortality rate": "9.79",
#         "Health problems": {
#             "Current health expenditure": 7.2,
#             "Physicians density": "2.49",
#             "Hospital bed density": "6"
#         }
#     }
# }
# {
#     "countrie": "belarus",
#     "population": 9383853.0,
#     "Population growth rate": 0.32,
#     "area": 207600.0,
#     "Map references": "Europe",
#     "Coastline": 0.0,
#     "elevation highest point": 346.0,
#     "elevation lowest point": 90.0,
#     "economy": {
#         "GDP": 63168000000.0,
#         "GDP_contribution_agriculture": 8.1,
#         "GDP_contribution_industry": 40.8,
#         "GDP_contribution_services": 51.1
#     },
#     "education": {
#         "school life expectancy": 15.0,
#         "Education expenditures": 4.7
#     },
#     "health": {
#         "life expectancy at birth": 74.54,
#         "infant mortality rate": "3.23",
#         "Health problems": {
#             "Current health expenditure": 6.4,
#             "Physicians density": "4.54",
#             "Hospital bed density": "10.8"
#         }
#     }
# }
# {
#     "countrie": "belgium",
#     "population": 11913633.0,
#     "Population growth rate": 0.55,
#     "area": 30528.0,
#     "Map references": "Europe",
#     "Coastline": 66.5,
#     "elevation highest point": 694.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 533028000000.0,
#         "GDP_contribution_agriculture": 0.7,
#         "GDP_contribution_industry": 22.1,
#         "GDP_contribution_services": 77.2
#     },
#     "education": {
#         "school life expectancy": 19.0,
#         "Education expenditures": 6.7
#     },
#     "health": {
#         "life expectancy at birth": 82.06,
#         "infant mortality rate": "3.15",
#         "Health problems": {
#             "Current health expenditure": 11.1,
#             "Physicians density": "6.08",
#             "Hospital bed density": "5.6"
#         }
#     }
# }
# {
#     "countrie": "belize",
#     "population": 419137.0,
#     "Population growth rate": 1.61,
#     "area": 22966.0,
#     "Map references": "Central America and the Caribbean",
#     "Coastline": 386.0,
#     "elevation highest point": 1124.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 1854000000.0,
#         "GDP_contribution_agriculture": 10.3,
#         "GDP_contribution_industry": 21.6,
#         "GDP_contribution_services": 68.0
#     },
#     "education": {
#         "school life expectancy": 13.0,
#         "Education expenditures": 8.7
#     },
#     "health": {
#         "life expectancy at birth": 76.08,
#         "infant mortality rate": "10.9",
#         "Health problems": {
#             "Current health expenditure": 6.9,
#             "Physicians density": "1.08",
#             "Hospital bed density": "1"
#         }
#     }
# }
# {
#     "countrie": "benin",
#     "population": 14219908.0,
#     "Population growth rate": 3.31,
#     "area": 112622.0,
#     "Map references": "Africa",
#     "Coastline": 121.0,
#     "elevation highest point": 675.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 10315000000.0,
#         "GDP_contribution_agriculture": 26.1,
#         "GDP_contribution_industry": 22.8,
#         "GDP_contribution_services": 51.1
#     },
#     "education": {
#         "school life expectancy": 11.0,
#         "Education expenditures": 3.0
#     },
#     "health": {
#         "life expectancy at birth": 62.6,
#         "infant mortality rate": "54.33",
#         "Health problems": {
#             "Current health expenditure": 2.6,
#             "Physicians density": "0.07",
#             "Hospital bed density": "0.5"
#         }
#     }
# }
# {
#     "countrie": "bermuda",
#     "population": 72576.0,
#     "Population growth rate": 0.32,
#     "area": 54.0,
#     "Map references": "North America",
#     "Coastline": 103.0,
#     "elevation highest point": 79.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 6127000000.0,
#         "GDP_contribution_agriculture": 0.9,
#         "GDP_contribution_industry": 5.3,
#         "GDP_contribution_services": 93.8
#     },
#     "education": {
#         "school life expectancy": 13.0,
#         "Education expenditures": 1.9
#     },
#     "health": {
#         "life expectancy at birth": 82.25,
#         "infant mortality rate": "2.17",
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "bhutan",
#     "population": 876181.0,
#     "Population growth rate": 0.96,
#     "area": 38394.0,
#     "Map references": "Asia",
#     "Coastline": 0.0,
#     "elevation highest point": 7570.0,
#     "elevation lowest point": 97.0,
#     "economy": {
#         "GDP": 2405000000.0,
#         "GDP_contribution_agriculture": 16.2,
#         "GDP_contribution_industry": 41.8,
#         "GDP_contribution_services": 42.0
#     },
#     "education": {
#         "school life expectancy": 13.0,
#         "Education expenditures": 7.0
#     },
#     "health": {
#         "life expectancy at birth": 73.01,
#         "infant mortality rate": "25.61",
#         "Health problems": {
#             "Current health expenditure": 4.4,
#             "Physicians density": "0.5",
#             "Hospital bed density": "1.7"
#         }
#     }
# }
# {
#     "countrie": "bosnia and herzegovina",
#     "population": 3807764.0,
#     "Population growth rate": 0.23,
#     "area": 51197.0,
#     "Map references": "Europe",
#     "Coastline": 20.0,
#     "elevation highest point": 2386.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 20078000000.0,
#         "GDP_contribution_agriculture": 6.8,
#         "GDP_contribution_industry": 28.9,
#         "GDP_contribution_services": 64.3
#     },
#     "education": {
#         "school life expectancy": 14.0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 78.22,
#         "infant mortality rate": "5.1",
#         "Health problems": {
#             "Current health expenditure": 9.8,
#             "Physicians density": "2.16",
#             "Hospital bed density": "3.5"
#         }
#     }
# }
# {
#     "countrie": "botswana",
#     "population": 2417596.0,
#     "Population growth rate": 1.37,
#     "area": 581730.0,
#     "Map references": "Africa",
#     "Coastline": 0.0,
#     "elevation highest point": 1495.0,
#     "elevation lowest point": 513.0,
#     "economy": {
#         "GDP": 18335000000.0,
#         "GDP_contribution_agriculture": 1.8,
#         "GDP_contribution_industry": 27.5,
#         "GDP_contribution_services": 70.6
#     },
#     "education": {
#         "school life expectancy": 12.0,
#         "Education expenditures": 8.7
#     },
#     "health": {
#         "life expectancy at birth": 66.04,
#         "infant mortality rate": "24.41",
#         "Health problems": {
#             "Current health expenditure": 6.2,
#             "Physicians density": "0.38",
#             "Hospital bed density": "1.8"
#         }
#     }
# }
# {
#     "countrie": "bouvet island",
#     "population": 0.0,
#     "Population growth rate": 0,
#     "area": 49.0,
#     "Map references": "Antarctic Region",
#     "Coastline": 29.6,
#     "elevation highest point": 780.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0,
#         "GDP_contribution_industry": 0,
#         "GDP_contribution_services": 0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 0,
#         "infant mortality rate": 0,
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "brazil",
#     "population": 218689757.0,
#     "Population growth rate": 0.64,
#     "area": 8515770.0,
#     "Map references": "South America",
#     "Coastline": 7491.0,
#     "elevation highest point": 2994.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 6.6,
#         "GDP_contribution_industry": 20.7,
#         "GDP_contribution_services": 72.7
#     },
#     "education": {
#         "school life expectancy": 16.0,
#         "Education expenditures": 6.0
#     },
#     "health": {
#         "life expectancy at birth": 76.1,
#         "infant mortality rate": "13.11",
#         "Health problems": {
#             "Current health expenditure": 10.3,
#             "Physicians density": "2.31",
#             "Hospital bed density": "2.1"
#         }
#     }
# }
# {
#     "countrie": "british indian ocean territory",
#     "population": 4200.0,
#     "Population growth rate": 0,
#     "area": 60.0,
#     "Map references": "Political Map of the World",
#     "Coastline": 698.0,
#     "elevation highest point": 9.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0,
#         "GDP_contribution_industry": 0,
#         "GDP_contribution_services": 0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 0,
#         "infant mortality rate": 0,
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "british virgin islands",
#     "population": 39369.0,
#     "Population growth rate": 1.87,
#     "area": 151.0,
#     "Map references": "Central America and the Caribbean",
#     "Coastline": 80.0,
#     "elevation highest point": 521.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 1380000000.0,
#         "GDP_contribution_agriculture": 0.2,
#         "GDP_contribution_industry": 6.8,
#         "GDP_contribution_services": 93.1
#     },
#     "education": {
#         "school life expectancy": 12.0,
#         "Education expenditures": 2.6
#     },
#     "health": {
#         "life expectancy at birth": 79.9,
#         "infant mortality rate": "13.77",
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "brunei",
#     "population": 485017.0,
#     "Population growth rate": 1.43,
#     "area": 5765.0,
#     "Map references": "Southeast Asia",
#     "Coastline": 161.0,
#     "elevation highest point": 1850.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 12130000000.0,
#         "GDP_contribution_agriculture": 1.2,
#         "GDP_contribution_industry": 56.6,
#         "GDP_contribution_services": 42.3
#     },
#     "education": {
#         "school life expectancy": 14.0,
#         "Education expenditures": 4.4
#     },
#     "health": {
#         "life expectancy at birth": 78.61,
#         "infant mortality rate": "10.26",
#         "Health problems": {
#             "Current health expenditure": 2.4,
#             "Physicians density": "1.61",
#             "Hospital bed density": "2.9"
#         }
#     }
# }
# {
#     "countrie": "bulgaria",
#     "population": 6827736.0,
#     "Population growth rate": 0.66,
#     "area": 110879.0,
#     "Map references": "Europe",
#     "Coastline": 354.0,
#     "elevation highest point": 2925.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 68489999999.99999,
#         "GDP_contribution_agriculture": 4.3,
#         "GDP_contribution_industry": 28.0,
#         "GDP_contribution_services": 67.4
#     },
#     "education": {
#         "school life expectancy": 14.0,
#         "Education expenditures": 4.0
#     },
#     "health": {
#         "life expectancy at birth": 75.83,
#         "infant mortality rate": "7.82",
#         "Health problems": {
#             "Current health expenditure": 8.5,
#             "Physicians density": "4.2",
#             "Hospital bed density": "7.5"
#         }
#     }
# }
# {
#     "countrie": "burkina faso",
#     "population": 22489126.0,
#     "Population growth rate": 2.46,
#     "area": 274200.0,
#     "Map references": "Africa",
#     "Coastline": 0.0,
#     "elevation highest point": 749.0,
#     "elevation lowest point": 200.0,
#     "economy": {
#         "GDP": 14271000000.0,
#         "GDP_contribution_agriculture": 31.0,
#         "GDP_contribution_industry": 23.9,
#         "GDP_contribution_services": 44.9
#     },
#     "education": {
#         "school life expectancy": 9.0,
#         "Education expenditures": 5.5
#     },
#     "health": {
#         "life expectancy at birth": 63.82,
#         "infant mortality rate": "48.17",
#         "Health problems": {
#             "Current health expenditure": 6.7,
#             "Physicians density": "0.09",
#             "Hospital bed density": "0.4"
#         }
#     }
# }
# {
#     "countrie": "burma",
#     "population": 57970293.0,
#     "Population growth rate": 0.75,
#     "area": 676578.0,
#     "Map references": "Southeast Asia",
#     "Coastline": 1930.0,
#     "elevation highest point": 5870.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 76606000000.0,
#         "GDP_contribution_agriculture": 24.1,
#         "GDP_contribution_industry": 35.6,
#         "GDP_contribution_services": 40.3
#     },
#     "education": {
#         "school life expectancy": 11.0,
#         "Education expenditures": 2.1
#     },
#     "health": {
#         "life expectancy at birth": 70.21,
#         "infant mortality rate": "32.2",
#         "Health problems": {
#             "Current health expenditure": 3.7,
#             "Physicians density": "0.74",
#             "Hospital bed density": "1"
#         }
#     }
# }
# {
#     "countrie": "burundi",
#     "population": 13162952.0,
#     "Population growth rate": 3.59,
#     "area": 27830.0,
#     "Map references": "Africa",
#     "Coastline": 0.0,
#     "elevation highest point": 2685.0,
#     "elevation lowest point": 772.0,
#     "economy": {
#         "GDP": 3027000000.0,
#         "GDP_contribution_agriculture": 39.5,
#         "GDP_contribution_industry": 16.4,
#         "GDP_contribution_services": 44.2
#     },
#     "education": {
#         "school life expectancy": 11.0,
#         "Education expenditures": 5.0
#     },
#     "health": {
#         "life expectancy at birth": 67.77,
#         "infant mortality rate": "36.75",
#         "Health problems": {
#             "Current health expenditure": 6.5,
#             "Physicians density": "0.07",
#             "Hospital bed density": "0.8"
#         }
#     }
# }
# {
#     "countrie": "cabo verde",
#     "population": 603901.0,
#     "Population growth rate": 1.19,
#     "area": 4033.0,
#     "Map references": "Africa",
#     "Coastline": 965.0,
#     "elevation highest point": 2829.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 1971000000.0,
#         "GDP_contribution_agriculture": 8.9,
#         "GDP_contribution_industry": 17.5,
#         "GDP_contribution_services": 73.7
#     },
#     "education": {
#         "school life expectancy": 13.0,
#         "Education expenditures": 7.6
#     },
#     "health": {
#         "life expectancy at birth": 74.02,
#         "infant mortality rate": "22.96",
#         "Health problems": {
#             "Current health expenditure": 6.0,
#             "Physicians density": "0.83",
#             "Hospital bed density": "2.1"
#         }
#     }
# }
# {
#     "countrie": "cambodia",
#     "population": 16891245.0,
#     "Population growth rate": 1.04,
#     "area": 181035.0,
#     "Map references": "Southeast Asia",
#     "Coastline": 443.0,
#     "elevation highest point": 1810.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 22090000000.0,
#         "GDP_contribution_agriculture": 25.3,
#         "GDP_contribution_industry": 32.8,
#         "GDP_contribution_services": 41.9
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 3.1
#     },
#     "health": {
#         "life expectancy at birth": 71.03,
#         "infant mortality rate": "28.75",
#         "Health problems": {
#             "Current health expenditure": 7.5,
#             "Physicians density": "0.19",
#             "Hospital bed density": "1.9"
#         }
#     }
# }
# {
#     "countrie": "cameroon",
#     "population": 30135732.0,
#     "Population growth rate": 2.73,
#     "area": 475440.0,
#     "Map references": "Africa",
#     "Coastline": 402.0,
#     "elevation highest point": 4045.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 34990000000.0,
#         "GDP_contribution_agriculture": 16.7,
#         "GDP_contribution_industry": 26.5,
#         "GDP_contribution_services": 56.8
#     },
#     "education": {
#         "school life expectancy": 12.0,
#         "Education expenditures": 3.2
#     },
#     "health": {
#         "life expectancy at birth": 63.74,
#         "infant mortality rate": "47.4",
#         "Health problems": {
#             "Current health expenditure": 3.8,
#             "Physicians density": "0.13",
#             "Hospital bed density": "1.3"
#         }
#     }
# }
# {
#     "countrie": "canada",
#     "population": 38516736.0,
#     "Population growth rate": 0.73,
#     "area": 9984670.0,
#     "Map references": "North America",
#     "Coastline": 36563.0,
#     "elevation highest point": 5959.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 1.6,
#         "GDP_contribution_industry": 28.2,
#         "GDP_contribution_services": 70.2
#     },
#     "education": {
#         "school life expectancy": 17.0,
#         "Education expenditures": 5.2
#     },
#     "health": {
#         "life expectancy at birth": 83.99,
#         "infant mortality rate": "4.31",
#         "Health problems": {
#             "Current health expenditure": 12.9,
#             "Physicians density": "2.44",
#             "Hospital bed density": "2.5"
#         }
#     }
# }
# {
#     "countrie": "cayman islands",
#     "population": 65483.0,
#     "Population growth rate": 1.79,
#     "area": 264.0,
#     "Map references": "Central America and the Caribbean",
#     "Coastline": 160.0,
#     "elevation highest point": 1.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 2250000000.0,
#         "GDP_contribution_agriculture": 0.3,
#         "GDP_contribution_industry": 7.4,
#         "GDP_contribution_services": 92.3
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 2.1
#     },
#     "health": {
#         "life expectancy at birth": 82.25,
#         "infant mortality rate": "7.47",
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "central african republic",
#     "population": 5552228.0,
#     "Population growth rate": 1.77,
#     "area": 622984.0,
#     "Map references": "Africa",
#     "Coastline": 0.0,
#     "elevation highest point": 1410.0,
#     "elevation lowest point": 335.0,
#     "economy": {
#         "GDP": 1937000000.0,
#         "GDP_contribution_agriculture": 43.2,
#         "GDP_contribution_industry": 16.0,
#         "GDP_contribution_services": 40.8
#     },
#     "education": {
#         "school life expectancy": 7.0,
#         "Education expenditures": 2.2
#     },
#     "health": {
#         "life expectancy at birth": 55.96,
#         "infant mortality rate": "81.74",
#         "Health problems": {
#             "Current health expenditure": 9.4,
#             "Physicians density": "0.07",
#             "Hospital bed density": "1"
#         }
#     }
# }
# {
#     "countrie": "chad",
#     "population": 18523165.0,
#     "Population growth rate": 3.05,
#     "area": 1.284,
#     "Map references": "Africa",
#     "Coastline": 0.0,
#     "elevation highest point": 3445.0,
#     "elevation lowest point": 160.0,
#     "economy": {
#         "GDP": 10912000000.0,
#         "GDP_contribution_agriculture": 52.3,
#         "GDP_contribution_industry": 14.7,
#         "GDP_contribution_services": 33.1
#     },
#     "education": {
#         "school life expectancy": 7.0,
#         "Education expenditures": 2.9
#     },
#     "health": {
#         "life expectancy at birth": 59.57,
#         "infant mortality rate": "63.99",
#         "Health problems": {
#             "Current health expenditure": 5.4,
#             "Physicians density": "0.06",
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "chile",
#     "population": 18549457.0,
#     "Population growth rate": 0.63,
#     "area": 756102.0,
#     "Map references": "South America",
#     "Coastline": 6435.0,
#     "elevation highest point": 6893.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 282655000000.0,
#         "GDP_contribution_agriculture": 4.2,
#         "GDP_contribution_industry": 32.8,
#         "GDP_contribution_services": 63.0
#     },
#     "education": {
#         "school life expectancy": 17.0,
#         "Education expenditures": 5.6
#     },
#     "health": {
#         "life expectancy at birth": 80.02,
#         "infant mortality rate": "6.41",
#         "Health problems": {
#             "Current health expenditure": 9.8,
#             "Physicians density": "2.84",
#             "Hospital bed density": "2.1"
#         }
#     }
# }
# {
#     "countrie": "china",
#     "population": 1413142846.0,
#     "Population growth rate": 0.18,
#     "area": 9596960.0,
#     "Map references": "Asia",
#     "Coastline": 14500.0,
#     "elevation highest point": 8849.0,
#     "elevation lowest point": -154.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 7.9,
#         "GDP_contribution_industry": 40.5,
#         "GDP_contribution_services": 51.6
#     },
#     "education": {
#         "school life expectancy": 14.0,
#         "Education expenditures": 3.6
#     },
#     "health": {
#         "life expectancy at birth": 78.23,
#         "infant mortality rate": "6.49",
#         "Health problems": {
#             "Current health expenditure": 5.6,
#             "Physicians density": "2.23",
#             "Hospital bed density": "4.3"
#         }
#     }
# }
# {
#     "countrie": "christmas island",
#     "population": 2205.0,
#     "Population growth rate": 1.11,
#     "area": 135.0,
#     "Map references": "Southeast Asia",
#     "Coastline": 138.9,
#     "elevation highest point": 361.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0,
#         "GDP_contribution_industry": 0,
#         "GDP_contribution_services": 0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 0,
#         "infant mortality rate": 0,
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "clipperton island",
#     "population": 0.0,
#     "Population growth rate": 0,
#     "area": 6.0,
#     "Map references": "Political Map of the World",
#     "Coastline": 11.1,
#     "elevation highest point": 29.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0,
#         "GDP_contribution_industry": 0,
#         "GDP_contribution_services": 0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 0,
#         "infant mortality rate": 0,
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "cocos keeling islands",
#     "population": 596.0,
#     "Population growth rate": 0,
#     "area": 14.0,
#     "Map references": "Southeast Asia",
#     "Coastline": 26.0,
#     "elevation highest point": 9.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0,
#         "GDP_contribution_industry": 0,
#         "GDP_contribution_services": 0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 0,
#         "infant mortality rate": 0,
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "colombia",
#     "population": 49336454.0,
#     "Population growth rate": 0.54,
#     "area": 1138910.0,
#     "Map references": "South America",
#     "Coastline": 0.0,
#     "elevation highest point": 5730.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 323255000000.0,
#         "GDP_contribution_agriculture": 7.2,
#         "GDP_contribution_industry": 30.8,
#         "GDP_contribution_services": 62.1
#     },
#     "education": {
#         "school life expectancy": 14.0,
#         "Education expenditures": 4.9
#     },
#     "health": {
#         "life expectancy at birth": 74.89,
#         "infant mortality rate": "11.65",
#         "Health problems": {
#             "Current health expenditure": 9.0,
#             "Physicians density": "2.33",
#             "Hospital bed density": "1.7"
#         }
#     }
# }
# {
#     "countrie": "comoros",
#     "population": 888378.0,
#     "Population growth rate": 1.34,
#     "area": 2235.0,
#     "Map references": "Africa",
#     "Coastline": 340.0,
#     "elevation highest point": 2360.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 1186000000.0,
#         "GDP_contribution_agriculture": 47.7,
#         "GDP_contribution_industry": 11.8,
#         "GDP_contribution_services": 40.5
#     },
#     "education": {
#         "school life expectancy": 11.0,
#         "Education expenditures": 2.6
#     },
#     "health": {
#         "life expectancy at birth": 67.5,
#         "infant mortality rate": "56.01",
#         "Health problems": {
#             "Current health expenditure": 5.4,
#             "Physicians density": "0.26",
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "congo democratic republic of the",
#     "population": 111859928.0,
#     "Population growth rate": 3.13,
#     "area": 2344858.0,
#     "Map references": "Africa",
#     "Coastline": 37.0,
#     "elevation highest point": 5110.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 47160000000.0,
#         "GDP_contribution_agriculture": 19.7,
#         "GDP_contribution_industry": 43.6,
#         "GDP_contribution_services": 36.7
#     },
#     "education": {
#         "school life expectancy": 11.0,
#         "Education expenditures": 2.7
#     },
#     "health": {
#         "life expectancy at birth": 62.23,
#         "infant mortality rate": "59.12",
#         "Health problems": {
#             "Current health expenditure": 4.1,
#             "Physicians density": "0.38",
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "congo republic of the",
#     "population": 5677493.0,
#     "Population growth rate": 2.33,
#     "area": 342000.0,
#     "Map references": "Africa",
#     "Coastline": 169.0,
#     "elevation highest point": 1020.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 8718000000.0,
#         "GDP_contribution_agriculture": 9.3,
#         "GDP_contribution_industry": 51.0,
#         "GDP_contribution_services": 39.7
#     },
#     "education": {
#         "school life expectancy": 11.0,
#         "Education expenditures": 4.5
#     },
#     "health": {
#         "life expectancy at birth": 62.51,
#         "infant mortality rate": "46.62",
#         "Health problems": {
#             "Current health expenditure": 4.5,
#             "Physicians density": "0.1",
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "cook islands",
#     "population": 19639.0,
#     "Population growth rate": 2.31,
#     "area": 236.0,
#     "Map references": "Oceania",
#     "Coastline": 120.0,
#     "elevation highest point": 652.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 299900000.0,
#         "GDP_contribution_agriculture": 5.1,
#         "GDP_contribution_industry": 12.7,
#         "GDP_contribution_services": 82.1
#     },
#     "education": {
#         "school life expectancy": 15.0,
#         "Education expenditures": 4.6
#     },
#     "health": {
#         "life expectancy at birth": 77.39,
#         "infant mortality rate": "15.53",
#         "Health problems": {
#             "Current health expenditure": 3.2,
#             "Physicians density": "1.41",
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "coral sea islands",
#     "population": 0.0,
#     "Population growth rate": 0,
#     "area": 3.0,
#     "Map references": "Oceania",
#     "Coastline": 3095.0,
#     "elevation highest point": 9.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0,
#         "GDP_contribution_industry": 0,
#         "GDP_contribution_services": 0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 0,
#         "infant mortality rate": 0,
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "costa rica",
#     "population": 5256612.0,
#     "Population growth rate": 0.98,
#     "area": 51100.0,
#     "Map references": "Central America and the Caribbean",
#     "Coastline": 1290.0,
#     "elevation highest point": 3819.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 61855000000.0,
#         "GDP_contribution_agriculture": 5.5,
#         "GDP_contribution_industry": 20.6,
#         "GDP_contribution_services": 73.9
#     },
#     "education": {
#         "school life expectancy": 17.0,
#         "Education expenditures": 6.7
#     },
#     "health": {
#         "life expectancy at birth": 79.87,
#         "infant mortality rate": "8.2",
#         "Health problems": {
#             "Current health expenditure": 7.9,
#             "Physicians density": "3.3",
#             "Hospital bed density": "1.1"
#         }
#     }
# }
# {
#     "countrie": "cote divoire",
#     "population": 29344847.0,
#     "Population growth rate": 2.16,
#     "area": 322463.0,
#     "Map references": "Africa",
#     "Coastline": 515.0,
#     "elevation highest point": 1752.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 42498000000.0,
#         "GDP_contribution_agriculture": 20.1,
#         "GDP_contribution_industry": 26.6,
#         "GDP_contribution_services": 53.3
#     },
#     "education": {
#         "school life expectancy": 11.0,
#         "Education expenditures": 3.4
#     },
#     "health": {
#         "life expectancy at birth": 62.71,
#         "infant mortality rate": "54.04",
#         "Health problems": {
#             "Current health expenditure": 3.3,
#             "Physicians density": "0.16",
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "croatia",
#     "population": 4169239.0,
#     "Population growth rate": 0.47,
#     "area": 56594.0,
#     "Map references": "Europe",
#     "Coastline": 0.0,
#     "elevation highest point": 1831.0,
# ...
#     "elevation highest point": 48.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 1020000000.0,
#         "GDP_contribution_agriculture": 0.5,
#         "GDP_contribution_industry": 8.9,
#         "GDP_contribution_services": 90.6
#     },
#     "education": {
#         "school life expectancy": 9.0,
#         "Education expenditures": 4.5
#     },
#     "health": {
#         "life expectancy at birth": 81.04,
#         "infant mortality rate": "11.32",
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "tuvalu",
#     "population": 11639.0,
#     "Population growth rate": 0.81,
#     "area": 26.0,
#     "Map references": "Oceania",
#     "Coastline": 24.0,
#     "elevation highest point": 5.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 40000000.0,
#         "GDP_contribution_agriculture": 24.5,
#         "GDP_contribution_industry": 5.6,
#         "GDP_contribution_services": 70.0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 68.69,
#         "infant mortality rate": "28.32",
#         "Health problems": {
#             "Current health expenditure": 21.5,
#             "Physicians density": "1.19",
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "uganda",
#     "population": 47729952.0,
#     "Population growth rate": 3.22,
#     "area": 241038.0,
#     "Map references": "Africa",
#     "Coastline": 0.0,
#     "elevation highest point": 5110.0,
#     "elevation lowest point": 614.0,
#     "economy": {
#         "GDP": 34683000000.0,
#         "GDP_contribution_agriculture": 28.2,
#         "GDP_contribution_industry": 21.1,
#         "GDP_contribution_services": 50.7
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 2.7
#     },
#     "health": {
#         "life expectancy at birth": 69.32,
#         "infant mortality rate": "29.44",
#         "Health problems": {
#             "Current health expenditure": 4.0,
#             "Physicians density": "0.15",
#             "Hospital bed density": "0.5"
#         }
#     }
# }
# {
#     "countrie": "ukraine",
#     "population": 43306477.0,
#     "Population growth rate": 0.52,
#     "area": 603550.0,
#     "Map references": "AsiaEurope",
#     "Coastline": 2782.0,
#     "elevation highest point": 2061.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 155082000000.0,
#         "GDP_contribution_agriculture": 12.2,
#         "GDP_contribution_industry": 28.6,
#         "GDP_contribution_services": 60.0
#     },
#     "education": {
#         "school life expectancy": 15.0,
#         "Education expenditures": 5.4
#     },
#     "health": {
#         "life expectancy at birth": 73.72,
#         "infant mortality rate": "7.21",
#         "Health problems": {
#             "Current health expenditure": 7.6,
#             "Physicians density": "2.99",
#             "Hospital bed density": "7.5"
#         }
#     }
# }
# {
#     "countrie": "united arab emirates",
#     "population": 9973449.0,
#     "Population growth rate": 0.58,
#     "area": 83600.0,
#     "Map references": "Middle East",
#     "Coastline": 1318.0,
#     "elevation highest point": 1905.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 421077000000.0,
#         "GDP_contribution_agriculture": 0.9,
#         "GDP_contribution_industry": 49.8,
#         "GDP_contribution_services": 49.2
#     },
#     "education": {
#         "school life expectancy": 16.0,
#         "Education expenditures": 3.9
#     },
#     "health": {
#         "life expectancy at birth": 79.75,
#         "infant mortality rate": "5.06",
#         "Health problems": {
#             "Current health expenditure": 5.5,
#             "Physicians density": "2.6",
#             "Hospital bed density": "1.4"
#         }
#     }
# }
# {
#     "countrie": "united kingdom",
#     "population": 68138484.0,
#     "Population growth rate": 0.49,
#     "area": 243610.0,
#     "Map references": "Europe",
#     "Coastline": 12429.0,
#     "elevation highest point": 1345.0,
#     "elevation lowest point": -4.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0.7,
#         "GDP_contribution_industry": 20.2,
#         "GDP_contribution_services": 79.2
#     },
#     "education": {
#         "school life expectancy": 17.0,
#         "Education expenditures": 5.5
#     },
#     "health": {
#         "life expectancy at birth": 82.05,
#         "infant mortality rate": "3.79",
#         "Health problems": {
#             "Current health expenditure": 12.0,
#             "Physicians density": "3",
#             "Hospital bed density": "2.5"
#         }
#     }
# }
# {
#     "countrie": "united states",
#     "population": 339665118.0,
#     "Population growth rate": 0.68,
#     "area": 9833517.0,
#     "Map references": "North America",
#     "Coastline": 19924.0,
#     "elevation highest point": 6190.0,
#     "elevation lowest point": -86.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0.9,
#         "GDP_contribution_industry": 19.1,
#         "GDP_contribution_services": 80.0
#     },
#     "education": {
#         "school life expectancy": 16.0,
#         "Education expenditures": 6.1
#     },
#     "health": {
#         "life expectancy at birth": 80.75,
#         "infant mortality rate": "5.12",
#         "Health problems": {
#             "Current health expenditure": 18.8,
#             "Physicians density": "2.61",
#             "Hospital bed density": "2.9"
#         }
#     }
# }
# {
#     "countrie": "uruguay",
#     "population": 3416264.0,
#     "Population growth rate": 0.27,
#     "area": 176215.0,
#     "Map references": "South America",
#     "Coastline": 660.0,
#     "elevation highest point": 514.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 56108000000.0,
#         "GDP_contribution_agriculture": 6.2,
#         "GDP_contribution_industry": 24.1,
#         "GDP_contribution_services": 69.7
#     },
#     "education": {
#         "school life expectancy": 19.0,
#         "Education expenditures": 4.6
#     },
#     "health": {
#         "life expectancy at birth": 78.66,
#         "infant mortality rate": "8.14",
#         "Health problems": {
#             "Current health expenditure": 9.2,
#             "Physicians density": "4.94",
#             "Hospital bed density": "2.4"
#         }
#     }
# }
# {
#     "countrie": "uzbekistan",
#     "population": 31360836.0,
#     "Population growth rate": 0.81,
#     "area": 447400.0,
#     "Map references": "Asia",
#     "Coastline": 0.0,
#     "elevation highest point": 4643.0,
#     "elevation lowest point": -12.0,
#     "economy": {
#         "GDP": 57789000000.0,
#         "GDP_contribution_agriculture": 17.9,
#         "GDP_contribution_industry": 33.7,
#         "GDP_contribution_services": 48.5
#     },
#     "education": {
#         "school life expectancy": 12.0,
#         "Education expenditures": 4.9
#     },
#     "health": {
#         "life expectancy at birth": 75.55,
#         "infant mortality rate": "18.55",
#         "Health problems": {
#             "Current health expenditure": 6.8,
#             "Physicians density": "2.37",
#             "Hospital bed density": "4"
#         }
#     }
# }
# {
#     "countrie": "vanuatu",
#     "population": 313046.0,
#     "Population growth rate": 1.59,
#     "area": 12189.0,
#     "Map references": "Oceania",
#     "Coastline": 2528.0,
#     "elevation highest point": 1877.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 870000000.0,
#         "GDP_contribution_agriculture": 27.3,
#         "GDP_contribution_industry": 11.8,
#         "GDP_contribution_services": 60.8
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 2.2
#     },
#     "health": {
#         "life expectancy at birth": 75.4,
#         "infant mortality rate": "14",
#         "Health problems": {
#             "Current health expenditure": 4.0,
#             "Physicians density": "0.17",
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "venezuela",
#     "population": 30518260.0,
#     "Population growth rate": 2.4,
#     "area": 912050.0,
#     "Map references": "South America",
#     "Coastline": 2800.0,
#     "elevation highest point": 4978.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 210100000000.0,
#         "GDP_contribution_agriculture": 4.7,
#         "GDP_contribution_industry": 40.4,
#         "GDP_contribution_services": 54.9
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 1.3
#     },
#     "health": {
#         "life expectancy at birth": 74.25,
#         "infant mortality rate": "14.1",
#         "Health problems": {
#             "Current health expenditure": 3.8,
#             "Physicians density": "1.73",
#             "Hospital bed density": "0.9"
#         }
#     }
# }
# {
#     "countrie": "vietnam",
#     "population": 104799174.0,
#     "Population growth rate": 0.93,
#     "area": 331210.0,
#     "Map references": "Southeast Asia",
#     "Coastline": 0.0,
#     "elevation highest point": 3144.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 259957000000.0,
#         "GDP_contribution_agriculture": 15.3,
#         "GDP_contribution_industry": 33.3,
#         "GDP_contribution_services": 51.3
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 4.1
#     },
#     "health": {
#         "life expectancy at birth": 75.79,
#         "infant mortality rate": "14.42",
#         "Health problems": {
#             "Current health expenditure": 4.7,
#             "Physicians density": "0.83",
#             "Hospital bed density": "3.2"
#         }
#     }
# }
# {
#     "countrie": "virgin islands",
#     "population": 104917.0,
#     "Population growth rate": 0.49,
#     "area": 1910.0,
#     "Map references": "Central America and the Caribbean",
#     "Coastline": 188.0,
#     "elevation highest point": 474.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 5182000000.0,
#         "GDP_contribution_agriculture": 2.0,
#         "GDP_contribution_industry": 20.0,
#         "GDP_contribution_services": 78.0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 80.49,
#         "infant mortality rate": "7.49",
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "wake island",
#     "population": 100.0,
#     "Population growth rate": 0,
#     "area": 7.0,
#     "Map references": "Oceania",
#     "Coastline": 19.3,
#     "elevation highest point": 8.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 0,
#         "GDP_contribution_industry": 0,
#         "GDP_contribution_services": 0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 0,
#         "infant mortality rate": 0,
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "wallis and futuna",
#     "population": 15929.0,
#     "Population growth rate": 0.23,
#     "area": 142.0,
#     "Map references": "Oceania",
#     "Coastline": 129.0,
#     "elevation highest point": 522.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 195000000.0,
#         "GDP_contribution_agriculture": 0,
#         "GDP_contribution_industry": 0,
#         "GDP_contribution_services": 0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 80.89,
#         "infant mortality rate": "3.94",
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "west bank",
#     "population": 3050760.0,
#     "Population growth rate": 1.66,
#     "area": 5860.0,
#     "Map references": "Middle East",
#     "Coastline": 0.0,
#     "elevation highest point": 1020.0,
#     "elevation lowest point": -431.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 2.9,
#         "GDP_contribution_industry": 19.5,
#         "GDP_contribution_services": 77.6
#     },
#     "education": {
#         "school life expectancy": 13.0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 76.63,
#         "infant mortality rate": "14.91",
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": "3.25",
#             "Hospital bed density": "1.3"
#         }
#     }
# }
# {
#     "countrie": "world",
#     "population": 7979261010.0,
#     "Population growth rate": 0,
#     "area": 510.072,
#     "Map references": "Physical Map of the World",
#     "Coastline": 95.0,
#     "elevation highest point": 8849.0,
#     "elevation lowest point": -3500.0,
#     "economy": {
#         "GDP": 0,
#         "GDP_contribution_agriculture": 6.4,
#         "GDP_contribution_industry": 30.0,
#         "GDP_contribution_services": 63.0
#     },
#     "education": {
#         "school life expectancy": 13.0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 70.5,
#         "infant mortality rate": "30.8",
#         "Health problems": {
#             "Current health expenditure": 0,
#             "Physicians density": 0,
#             "Hospital bed density": 0
#         }
#     }
# }
# {
#     "countrie": "yemen",
#     "population": 31565602.0,
#     "Population growth rate": 1.83,
#     "area": 527968.0,
#     "Map references": "Middle East",
#     "Coastline": 1906.0,
#     "elevation highest point": 3666.0,
#     "elevation lowest point": 0.0,
#     "economy": {
#         "GDP": 54356000000.0,
#         "GDP_contribution_agriculture": 20.3,
#         "GDP_contribution_industry": 11.8,
#         "GDP_contribution_services": 67.9
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 0
#     },
#     "health": {
#         "life expectancy at birth": 67.83,
#         "infant mortality rate": "45.54",
#         "Health problems": {
#             "Current health expenditure": 4.3,
#             "Physicians density": "0.53",
#             "Hospital bed density": "0.7"
#         }
#     }
# }
# {
#     "countrie": "zambia",
#     "population": 20216029.0,
#     "Population growth rate": 2.86,
#     "area": 752618.0,
#     "Map references": "Africa",
#     "Coastline": 0.0,
#     "elevation highest point": 2330.0,
#     "elevation lowest point": 329.0,
#     "economy": {
#         "GDP": 25710000000.0,
#         "GDP_contribution_agriculture": 7.5,
#         "GDP_contribution_industry": 35.3,
#         "GDP_contribution_services": 57.0
#     },
#     "education": {
#         "school life expectancy": 0,
#         "Education expenditures": 3.7
#     },
#     "health": {
#         "life expectancy at birth": 66.6,
#         "infant mortality rate": "36.33",
#         "Health problems": {
#             "Current health expenditure": 5.6,
#             "Physicians density": "1.17",
#             "Hospital bed density": "2"
#         }
#     }
# }
# {
#     "countrie": "zimbabwe",
#     "population": 15418674.0,
#     "Population growth rate": 1.95,
#     "area": 390757.0,
#     "Map references": "Africa",
#     "Coastline": 0.0,
#     "elevation highest point": 2592.0,
#     "elevation lowest point": 162.0,
#     "economy": {
#         "GDP": 21441000000.0,
#         "GDP_contribution_agriculture": 12.0,
#         "GDP_contribution_industry": 22.2,
#         "GDP_contribution_services": 65.8
#     },
#     "education": {
#         "school life expectancy": 11.0,
#         "Education expenditures": 3.9
#     },
#     "health": {
#         "life expectancy at birth": 63.79,
#         "infant mortality rate": "27.67",
#         "Health problems": {
#             "Current health expenditure": 3.4,
#             "Physicians density": "0.2",
#             "Hospital bed density": "1.7"
#         }
#     }
# }

# %%
import re

def limpiar(text: str) -> float:
    #result = re.search(r'(-?[\d,.]+)\s*m?', str(text))
    result = re.search(r'(-?[\d,]+)\s*m?', text)

    if result:
        extracted_number = result.group(1)
        if ',' in extracted_number:
            number = extracted_number.replace(',', '')
            return float(number)
        else:
            return float(result.group(1)) if result.group(1) != '.' else 0

    return 0

print(limpiar('Mt. Fogo (a volcano on Fogo Island) 2,829 '))
# Out:
# 2829.0
